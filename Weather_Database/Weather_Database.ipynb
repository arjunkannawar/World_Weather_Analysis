# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1db5d0559ca44b042fc0ee3e3fdac1a0

# %%
# Create an empty list to hold the weather data.
city_data = []
city_data_new_df = [] #Creating an empty Data Frame to hold the array of dcitionaries into a data frame.
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        #city_current_description = city_weather["weather"]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        #city_current_description = city_weather["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print (e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | bredasdorp
# Processing Record 2 of Set 15 | ushuaia
# Processing Record 3 of Set 15 | nebbi
# Processing Record 4 of Set 15 | katha
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 15 | sisimiut
# Processing Record 6 of Set 15 | emba
# Processing Record 7 of Set 15 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 15 | yellowknife
# Processing Record 9 of Set 15 | mataura
# Processing Record 10 of Set 15 | vaini
# Processing Record 11 of Set 15 | merauke
# Processing Record 12 of Set 15 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 15 | puerto ayora
# Processing Record 14 of Set 15 | cidreira
# Processing Record 15 of Set 15 | mount gambier
# Processing Record 16 of Set 15 | ekhabi
# Processing Record 17 of Set 15 | new norfolk
# Processing Record 18 of Set 15 | gerash
# Processing Record 19 of Set 15 | baghdad
# Processing Record 20 of Set 15 | qaanaaq
# Processing Record 21 of Set 15 | port alfred
# Processing Record 22 of Set 15 | bluff
# Processing Record 23 of Set 15 | nikolskoye
# Processing Record 24 of Set 15 | iqaluit
# Processing Record 25 of Set 15 | basco
# Processing Record 26 of Set 15 | chepareria
# Processing Record 27 of Set 15 | hilo
# Processing Record 28 of Set 15 | beloha
# Processing Record 29 of Set 15 | kavieng
# Processing Record 30 of Set 15 | mar del plata
# Processing Record 31 of Set 15 | evensk
# Processing Record 32 of Set 15 | portland
# Processing Record 33 of Set 15 | sawtell
# Processing Record 34 of Set 15 | saint george
# Processing Record 35 of Set 15 | butaritari
# Processing Record 36 of Set 15 | hithadhoo
# Processing Record 37 of Set 15 | san quintin
# Processing Record 38 of Set 15 | saint-pierre
# Processing Record 39 of Set 15 | muros
# Processing Record 40 of Set 15 | bambous virieux
# Processing Record 41 of Set 15 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 15 | clearlake
# Processing Record 43 of Set 15 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 15 | martapura
# Processing Record 45 of Set 15 | jaisalmer
# Processing Record 46 of Set 15 | berbera
# Processing Record 47 of Set 15 | hofn
# Processing Record 48 of Set 15 | castro
# Processing Record 49 of Set 15 | tuatapere
# Processing Record 50 of Set 15 | kushima
# Processing Record 1 of Set 16 | abu samrah
# Processing Record 2 of Set 16 | jambi
# Processing Record 3 of Set 16 | bangkal
# Processing Record 4 of Set 16 | kibala
# Processing Record 5 of Set 16 | jamestown
# Processing Record 6 of Set 16 | hamilton
# Processing Record 7 of Set 16 | honningsvag
# Processing Record 8 of Set 16 | bardiyah
# Processing Record 9 of Set 16 | cape town
# Processing Record 10 of Set 16 | shimoda
# Processing Record 11 of Set 16 | tecoanapa
# Processing Record 12 of Set 16 | lefka
# Processing Record 13 of Set 16 | honiara
# Processing Record 14 of Set 16 | sayat
# Processing Record 15 of Set 16 | albany
# Processing Record 16 of Set 16 | mazatlan
# Processing Record 17 of Set 16 | dunedin
# Processing Record 18 of Set 16 | manoel urbano
# Processing Record 19 of Set 16 | esperance
# Processing Record 20 of Set 16 | mogzon
# Processing Record 21 of Set 16 | garoua boulai
# Processing Record 22 of Set 16 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 16 | coihaique
# Processing Record 24 of Set 16 | barrow
# Processing Record 25 of Set 16 | thompson
# Processing Record 26 of Set 16 | saint-philippe
# Processing Record 27 of Set 16 | richards bay
# Processing Record 28 of Set 16 | dalian
# Processing Record 29 of Set 16 | clyde river
# Processing Record 30 of Set 16 | rikitea
# Processing Record 31 of Set 16 | kavaratti
# Processing Record 32 of Set 16 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 16 | sarakhs
# Processing Record 34 of Set 16 | oistins
# Processing Record 35 of Set 16 | sur
# Processing Record 36 of Set 16 | zhigansk
# Processing Record 37 of Set 16 | chuy
# Processing Record 38 of Set 16 | norman wells
# Processing Record 39 of Set 16 | hobart
# Processing Record 40 of Set 16 | bonavista
# Processing Record 41 of Set 16 | sitka
# Processing Record 42 of Set 16 | bathsheba
# Processing Record 43 of Set 16 | punta arenas
# Processing Record 44 of Set 16 | hay river
# Processing Record 45 of Set 16 | busselton
# Processing Record 46 of Set 16 | nautla
# Processing Record 47 of Set 16 | geraldton
# Processing Record 48 of Set 16 | faya
# Processing Record 49 of Set 16 | vidim
# Processing Record 50 of Set 16 | doha
# Processing Record 1 of Set 17 | young
# Processing Record 2 of Set 17 | tuktoyaktuk
# Processing Record 3 of Set 17 | dmitriyevka
# Processing Record 4 of Set 17 | kasongo-lunda
# Processing Record 5 of Set 17 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 17 | esfahan
# Processing Record 7 of Set 17 | port macquarie
# Processing Record 8 of Set 17 | sabinas
# Processing Record 9 of Set 17 | faanui
# Processing Record 10 of Set 17 | lagoa
# Processing Record 11 of Set 17 | kahului
# Processing Record 12 of Set 17 | el tigre
# Processing Record 13 of Set 17 | mlonggo
# Processing Record 14 of Set 17 | ponta do sol
# Processing Record 15 of Set 17 | luanda
# Processing Record 16 of Set 17 | brae
# Processing Record 17 of Set 17 | qabis
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 17 | lebu
# Processing Record 19 of Set 17 | ukiah
# Processing Record 20 of Set 17 | avarua
# Processing Record 21 of Set 17 | requena
# Processing Record 22 of Set 17 | krasnyy yar
# Processing Record 23 of Set 17 | bukachacha
# Processing Record 24 of Set 17 | nemuro
# Processing Record 25 of Set 17 | mastic beach
# Processing Record 26 of Set 17 | lompoc
# Processing Record 27 of Set 17 | san rafael
# Processing Record 28 of Set 17 | college
# Processing Record 29 of Set 17 | torbay
# Processing Record 30 of Set 17 | ayer itam
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 17 | hermanus
# Processing Record 32 of Set 17 | farafangana
# Processing Record 33 of Set 17 | payson
# Processing Record 34 of Set 17 | east london
# Processing Record 35 of Set 17 | ilulissat
# Processing Record 36 of Set 17 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 17 | bairiki
# Processing Record 38 of Set 17 | juneau
# Processing Record 39 of Set 17 | severo-kurilsk
# Processing Record 40 of Set 17 | souillac
# Processing Record 41 of Set 17 | praia
# Processing Record 42 of Set 17 | aklavik
# Processing Record 43 of Set 17 | qaqortoq
# Processing Record 44 of Set 17 | coquimbo
# Processing Record 45 of Set 17 | taksimo
# Processing Record 46 of Set 17 | sabang
# Processing Record 47 of Set 17 | touros
# Processing Record 48 of Set 17 | vincennes
# Processing Record 49 of Set 17 | chokurdakh
# Processing Record 50 of Set 17 | tasiilaq
# Processing Record 1 of Set 18 | iracoubo
# Processing Record 2 of Set 18 | gazli
# Processing Record 3 of Set 18 | pedernales
# Processing Record 4 of Set 18 | sorong
# Processing Record 5 of Set 18 | kaitangata
# Processing Record 6 of Set 18 | masuda
# Processing Record 7 of Set 18 | sabha
# Processing Record 8 of Set 18 | ca mau
# Processing Record 9 of Set 18 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 18 | eureka
# Processing Record 11 of Set 18 | tiksi
# Processing Record 12 of Set 18 | mattawa
# Processing Record 13 of Set 18 | arona
# Processing Record 14 of Set 18 | sao jose da coroa grande
# Processing Record 15 of Set 18 | qingdao
# Processing Record 16 of Set 18 | hasaki
# Processing Record 17 of Set 18 | zychlin
# Processing Record 18 of Set 18 | champerico
# Processing Record 19 of Set 18 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 18 | upernavik
# Processing Record 21 of Set 18 | ixtapa
# Processing Record 22 of Set 18 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 18 | zhangjiakou
# Processing Record 24 of Set 18 | vardo
# Processing Record 25 of Set 18 | carnaiba
# Processing Record 26 of Set 18 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 18 | dikson
# Processing Record 28 of Set 18 | arraial do cabo
# Processing Record 29 of Set 18 | mayumba
# Processing Record 30 of Set 18 | ghanzi
# Processing Record 31 of Set 18 | poum
# Processing Record 32 of Set 18 | grand-santi
# Processing Record 33 of Set 18 | mahebourg
# Processing Record 34 of Set 18 | kuala terengganu
# Processing Record 35 of Set 18 | pangnirtung
# Processing Record 36 of Set 18 | pevek
# Processing Record 37 of Set 18 | katowice
# Processing Record 38 of Set 18 | mwene-ditu
# Processing Record 39 of Set 18 | atuona
# Processing Record 40 of Set 18 | batsfjord
# Processing Record 41 of Set 18 | yerbogachen
# Processing Record 42 of Set 18 | hameenlinna
# Processing Record 43 of Set 18 | teruel
# Processing Record 44 of Set 18 | sarangani
# Processing Record 45 of Set 18 | bethel
# Processing Record 46 of Set 18 | plettenberg bay
# Processing Record 47 of Set 18 | port elizabeth
# Processing Record 48 of Set 18 | ambilobe
# Processing Record 49 of Set 18 | flagstaff
# Processing Record 50 of Set 18 | asau
# Processing Record 1 of Set 19 | lata
# Processing Record 2 of Set 19 | ruatoria
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 19 | port lincoln
# Processing Record 4 of Set 19 | hambantota
# Processing Record 5 of Set 19 | aligudarz
# Processing Record 6 of Set 19 | balkanabat
# Processing Record 7 of Set 19 | kutum
# Processing Record 8 of Set 19 | saldanha
# Processing Record 9 of Set 19 | kudahuvadhoo
# Processing Record 10 of Set 19 | bengkulu
# Processing Record 11 of Set 19 | kapaa
# Processing Record 12 of Set 19 | lola
# Processing Record 13 of Set 19 | olafsvik
# Processing Record 14 of Set 19 | georgetown
# Processing Record 15 of Set 19 | taoudenni
# Processing Record 16 of Set 19 | ogaminana
# Processing Record 17 of Set 19 | half moon bay
# Processing Record 18 of Set 19 | buraydah
# Processing Record 19 of Set 19 | los algarrobos
# Processing Record 20 of Set 19 | guerrero negro
# Processing Record 21 of Set 19 | gimli
# Processing Record 22 of Set 19 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 19 | cabra
# Processing Record 24 of Set 19 | camocim
# Processing Record 25 of Set 19 | roald
# Processing Record 26 of Set 19 | panjab
# Processing Record 27 of Set 19 | subaytilah
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 19 | okhotsk
# Processing Record 29 of Set 19 | gandevi
# Processing Record 30 of Set 19 | rawson
# Processing Record 31 of Set 19 | masuguru
# Processing Record 32 of Set 19 | ostrovnoy
# Processing Record 33 of Set 19 | port blair
# Processing Record 34 of Set 19 | saint-francois
# Processing Record 35 of Set 19 | huazhou
# Processing Record 36 of Set 19 | fortuna
# Processing Record 37 of Set 19 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 19 | cherskiy
# Processing Record 39 of Set 19 | coahuayana
# Processing Record 40 of Set 19 | jackson
# Processing Record 41 of Set 19 | cheuskiny
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 19 | meulaboh
# Processing Record 43 of Set 19 | kirakira
# Processing Record 44 of Set 19 | prince rupert
# Processing Record 45 of Set 19 | viligili
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 19 | hot springs
# Processing Record 47 of Set 19 | takoradi
# Processing Record 48 of Set 19 | nouadhibou
# Processing Record 49 of Set 19 | erzin
# Processing Record 50 of Set 19 | fairbanks
# Processing Record 1 of Set 20 | bandarbeyla
# Processing Record 2 of Set 20 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 20 | jalu
# Processing Record 4 of Set 20 | waingapu
# Processing Record 5 of Set 20 | bombay
# Processing Record 6 of Set 20 | tsaghkahovit
# Processing Record 7 of Set 20 | fougamou
# Processing Record 8 of Set 20 | victoria
# Processing Record 9 of Set 20 | longyearbyen
# Processing Record 10 of Set 20 | san-pedro
# Processing Record 11 of Set 20 | karratha
# Processing Record 12 of Set 20 | gravdal
# Processing Record 13 of Set 20 | hobyo
# Processing Record 14 of Set 20 | banepa
# Processing Record 15 of Set 20 | la ronge
# Processing Record 16 of Set 20 | reforma
# Processing Record 17 of Set 20 | cockburn town
# Processing Record 18 of Set 20 | bollnas
# Processing Record 19 of Set 20 | temaraia
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 20 | komsomolskiy
# Processing Record 21 of Set 20 | port hardy
# Processing Record 22 of Set 20 | kendrapara
# Processing Record 23 of Set 20 | airai
# Processing Record 24 of Set 20 | bundaberg
# Processing Record 25 of Set 20 | kieta
# Processing Record 26 of Set 20 | bay roberts
# Processing Record 27 of Set 20 | waddan
# Processing Record 28 of Set 20 | cuamba
# Processing Record 29 of Set 20 | vila velha
# Processing Record 30 of Set 20 | narsaq
# Processing Record 31 of Set 20 | kenai
# Processing Record 32 of Set 20 | coetupo
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 20 | palimbang
# Processing Record 34 of Set 20 | kruisfontein
# Processing Record 35 of Set 20 | macamic
# Processing Record 36 of Set 20 | hualmay
# Processing Record 37 of Set 20 | carnarvon
# Processing Record 38 of Set 20 | avera
# Processing Record 39 of Set 20 | salalah
# Processing Record 40 of Set 20 | orlik
# Processing Record 41 of Set 20 | norsup
# Processing Record 42 of Set 20 | petlad
# Processing Record 43 of Set 20 | natal
# Processing Record 44 of Set 20 | kodiak
# Processing Record 45 of Set 20 | waycross
# Processing Record 46 of Set 20 | panaba
# Processing Record 47 of Set 20 | ngukurr
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 20 | cabo san lucas
# Processing Record 49 of Set 20 | krasnoselkup
# Processing Record 50 of Set 20 | san ignacio
# Processing Record 1 of Set 21 | scottsbluff
# Processing Record 2 of Set 21 | camana
# Processing Record 3 of Set 21 | leningradskiy
# Processing Record 4 of Set 21 | nanortalik
# Processing Record 5 of Set 21 | yuci
# Processing Record 6 of Set 21 | haines junction
# Processing Record 7 of Set 21 | birjand
# Processing Record 8 of Set 21 | raga
# Processing Record 9 of Set 21 | lidkoping
# Processing Record 10 of Set 21 | boralday
# Processing Record 11 of Set 21 | kollam
# Processing Record 12 of Set 21 | batagay-alyta
# Processing Record 13 of Set 21 | bonthe
# Processing Record 14 of Set 21 | cabedelo
# Processing Record 15 of Set 21 | kloulklubed
# Processing Record 16 of Set 21 | luderitz
# Processing Record 17 of Set 21 | broken hill
# Processing Record 18 of Set 21 | chatra
# Processing Record 19 of Set 21 | hovd
# Processing Record 20 of Set 21 | cayenne
# Processing Record 21 of Set 21 | yeletskiy
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 21 | acarau
# Processing Record 23 of Set 21 | morrope
# Processing Record 24 of Set 21 | krasnokamensk
# Processing Record 25 of Set 21 | armacao dos buzios
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 21 | havelock
# Processing Record 27 of Set 21 | nelson bay
# Processing Record 28 of Set 21 | port harcourt
# Processing Record 29 of Set 21 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 21 | yulara
# Processing Record 31 of Set 21 | izhmorskiy
# Processing Record 32 of Set 21 | muisne
# Processing Record 33 of Set 21 | khatanga
# Processing Record 34 of Set 21 | bereda
# Processing Record 35 of Set 21 | halalo
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 21 | tawnat
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 21 | buala
# Processing Record 38 of Set 21 | bosaso
# Processing Record 39 of Set 21 | zharkent
# Processing Record 40 of Set 21 | grenaa
# Processing Record 41 of Set 21 | egvekinot
# Processing Record 42 of Set 21 | nouakchott
# Processing Record 43 of Set 21 | buqayq
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 21 | yarmouth
# Processing Record 45 of Set 21 | whakatane
# Processing Record 46 of Set 21 | lashio
# Processing Record 47 of Set 21 | iralaya
# Processing Record 48 of Set 21 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 21 | san andres
# Processing Record 50 of Set 21 | balikpapan
# Processing Record 1 of Set 22 | beyneu
# Processing Record 2 of Set 22 | alofi
# Processing Record 3 of Set 22 | safford
# Processing Record 4 of Set 22 | tshela
# Processing Record 5 of Set 22 | roslavl
# Processing Record 6 of Set 22 | praia da vitoria
# Processing Record 7 of Set 22 | isangel
# Processing Record 8 of Set 22 | broome
# Processing Record 9 of Set 22 | taree
# Processing Record 10 of Set 22 | raipur
# Processing Record 11 of Set 22 | tautira
# Processing Record 12 of Set 22 | bar harbor
# Processing Record 13 of Set 22 | tarakan
# Processing Record 14 of Set 22 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 22 | piacabucu
# Processing Record 16 of Set 22 | sola
# Processing Record 17 of Set 22 | samarai
# Processing Record 18 of Set 22 | malindi
# Processing Record 19 of Set 22 | marawi
# Processing Record 20 of Set 22 | leshukonskoye
# Processing Record 21 of Set 22 | sobolevo
# Processing Record 22 of Set 22 | inyonga
# Processing Record 23 of Set 22 | saint anthony
# Processing Record 24 of Set 22 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 22 | cap-aux-meules
# Processing Record 26 of Set 22 | constitucion
# Processing Record 27 of Set 22 | lorengau
# Processing Record 28 of Set 22 | nishihara
# Processing Record 29 of Set 22 | odweyne
# Processing Record 30 of Set 22 | mawlaik
# Processing Record 31 of Set 22 | namibe
# Processing Record 32 of Set 22 | shanghai
# Processing Record 33 of Set 22 | gitarama
# Processing Record 34 of Set 22 | iquitos
# Processing Record 35 of Set 22 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 22 | walvis bay
# Processing Record 37 of Set 22 | dillon
# Processing Record 38 of Set 22 | tura
# Processing Record 39 of Set 22 | kampot
# Processing Record 40 of Set 22 | urdoma
# Processing Record 41 of Set 22 | kandrian
# Processing Record 42 of Set 22 | lavrentiya
# Processing Record 43 of Set 22 | paamiut
# Processing Record 44 of Set 22 | ajdabiya
# Processing Record 45 of Set 22 | ribeira do pombal
# Processing Record 46 of Set 22 | ostersund
# Processing Record 47 of Set 22 | senneterre
# Processing Record 48 of Set 22 | jasper
# Processing Record 49 of Set 22 | gualaquiza
# Processing Record 50 of Set 22 | naifaru
# Processing Record 1 of Set 23 | wahran
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 23 | barguzin
# Processing Record 3 of Set 23 | khorixas
# Processing Record 4 of Set 23 | gorontalo
# Processing Record 5 of Set 23 | talcahuano
# Processing Record 6 of Set 23 | mana
# Processing Record 7 of Set 23 | mahasamund
# Processing Record 8 of Set 23 | talnakh
# Processing Record 9 of Set 23 | aquiraz
# Processing Record 10 of Set 23 | qasigiannguit
# Processing Record 11 of Set 23 | sandviken
# Processing Record 12 of Set 23 | okha
# Processing Record 13 of Set 23 | deputatskiy
# Processing Record 14 of Set 23 | codrington
# Processing Record 15 of Set 23 | russell
# Processing Record 16 of Set 23 | sinnamary
# Processing Record 17 of Set 23 | atar
# Processing Record 18 of Set 23 | marshall
# Processing Record 19 of Set 23 | uruzgan
# Processing Record 20 of Set 23 | natitingou
# Processing Record 21 of Set 23 | saryg-sep
# Processing Record 22 of Set 23 | sinjah
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 23 | laguna
# Processing Record 24 of Set 23 | iberia
# Processing Record 25 of Set 23 | tsabong
# Processing Record 26 of Set 23 | maridi
# Processing Record 27 of Set 23 | vostok
# Processing Record 28 of Set 23 | fort nelson
# Processing Record 29 of Set 23 | rawannawi
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 23 | sao filipe
# Processing Record 31 of Set 23 | quatre cocos
# Processing Record 32 of Set 23 | port hawkesbury
# Processing Record 33 of Set 23 | ravar
# Processing Record 34 of Set 23 | aykhal
# Processing Record 35 of Set 23 | buenos aires
# Processing Record 36 of Set 23 | nara
# Processing Record 37 of Set 23 | itoman
# Processing Record 38 of Set 23 | perth
# Processing Record 39 of Set 23 | rio gallegos
# Processing Record 40 of Set 23 | batemans bay
# Processing Record 41 of Set 23 | huarmey
# Processing Record 42 of Set 23 | emerald
# Processing Record 43 of Set 23 | trossingen
# Processing Record 44 of Set 23 | saint-louis
# Processing Record 45 of Set 23 | beidao
# Processing Record 46 of Set 23 | provideniya
# Processing Record 47 of Set 23 | berlevag
# Processing Record 48 of Set 23 | linxia
# Processing Record 49 of Set 23 | fukue
# Processing Record 50 of Set 23 | sattahip
# Processing Record 1 of Set 24 | pocerski pricinovic
# Processing Record 2 of Set 24 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 24 | yei
# Processing Record 4 of Set 24 | grand gaube
# Processing Record 5 of Set 24 | ambulu
# Processing Record 6 of Set 24 | stoke-on-trent
# Processing Record 7 of Set 24 | mehamn
# Processing Record 8 of Set 24 | ribeira grande
# Processing Record 9 of Set 24 | bilma
# Processing Record 10 of Set 24 | salinas
# Processing Record 11 of Set 24 | vathi
# Processing Record 12 of Set 24 | nagar karnul
# Processing Record 13 of Set 24 | san cristobal
# Processing Record 14 of Set 24 | pisco
# Processing Record 15 of Set 24 | trelew
# Processing Record 16 of Set 24 | makakilo city
# Processing Record 17 of Set 24 | katsuura
# Processing Record 18 of Set 24 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 24 | tiruchchendur
# Processing Record 20 of Set 24 | bousso
# Processing Record 21 of Set 24 | banff
# Processing Record 22 of Set 24 | san policarpo
# Processing Record 23 of Set 24 | humaita
# Processing Record 24 of Set 24 | bijie
# Processing Record 25 of Set 24 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 24 | roura
# Processing Record 27 of Set 24 | buriti dos lopes
# Processing Record 28 of Set 24 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 24 | quimper
# Processing Record 30 of Set 24 | sao raimundo das mangabeiras
# Processing Record 31 of Set 24 | samalaeulu
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 24 | san patricio
# Processing Record 33 of Set 24 | podyuga
# Processing Record 34 of Set 24 | kodinar
# Processing Record 35 of Set 24 | nieuw amsterdam
# Processing Record 36 of Set 24 | naushahro firoz
# Processing Record 37 of Set 24 | bose
# Processing Record 38 of Set 24 | kijang
# Processing Record 39 of Set 24 | powell river
# Processing Record 40 of Set 24 | meyungs
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 24 | mancora
# Processing Record 42 of Set 24 | grindavik
# Processing Record 43 of Set 24 | amazar
# Processing Record 44 of Set 24 | hohhot
# Processing Record 45 of Set 24 | kawalu
# Processing Record 46 of Set 24 | port-gentil
# Processing Record 47 of Set 24 | sucua
# Processing Record 48 of Set 24 | casablanca
# Processing Record 49 of Set 24 | shar
# Processing Record 50 of Set 24 | mareeba
# Processing Record 1 of Set 25 | matamoros
# Processing Record 2 of Set 25 | savannah bight
# Processing Record 3 of Set 25 | ilek
# Processing Record 4 of Set 25 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 25 | adre
# Processing Record 6 of Set 25 | shieli
# Processing Record 7 of Set 25 | vanderhoof
# Processing Record 8 of Set 25 | manicore
# Processing Record 9 of Set 25 | ginir
# Processing Record 10 of Set 25 | nantucket
# Processing Record 11 of Set 25 | warqla
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 25 | amahai
# Processing Record 13 of Set 25 | puerto quijarro
# Processing Record 14 of Set 25 | manzhouli
# Processing Record 15 of Set 25 | husavik
# Processing Record 16 of Set 25 | mayo
# Processing Record 17 of Set 25 | korla
# Processing Record 18 of Set 25 | itarema
# Processing Record 19 of Set 25 | liverpool
# Processing Record 20 of Set 25 | ust-kamchatsk
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 25 | soe
# Processing Record 22 of Set 25 | srednekolymsk
# Processing Record 23 of Set 25 | villarrica
# Processing Record 24 of Set 25 | mackenzie
# Processing Record 25 of Set 25 | lumberton
# Processing Record 26 of Set 25 | kralendijk
# Processing Record 27 of Set 25 | deniliquin
# Processing Record 28 of Set 25 | hami
# Processing Record 29 of Set 25 | yarega
# Processing Record 30 of Set 25 | mweka
# Processing Record 31 of Set 25 | bhayavadar
# Processing Record 32 of Set 25 | uzumlu
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 25 | balen
# Processing Record 34 of Set 25 | wetaskiwin
# Processing Record 35 of Set 25 | asfi
# Processing Record 36 of Set 25 | dalbandin
# Processing Record 37 of Set 25 | ormara
# Processing Record 38 of Set 25 | najran
# Processing Record 39 of Set 25 | antofagasta
# Processing Record 40 of Set 25 | eaton socon
# Processing Record 41 of Set 25 | alta floresta
# Processing Record 42 of Set 25 | boden
# Processing Record 43 of Set 25 | kaliua
# Processing Record 44 of Set 25 | sidney
# Processing Record 45 of Set 25 | saskylakh
# Processing Record 46 of Set 25 | kerrville
# Processing Record 47 of Set 25 | leh
# Processing Record 48 of Set 25 | alexandria
# Processing Record 49 of Set 25 | sao joao da barra
# Processing Record 50 of Set 25 | qurayyat
# Processing Record 1 of Set 26 | vao
# Processing Record 2 of Set 26 | san vicente
# Processing Record 3 of Set 26 | freeport
# Processing Record 4 of Set 26 | visby
# Processing Record 5 of Set 26 | murdochville
# Processing Record 6 of Set 26 | devils lake
# Processing Record 7 of Set 26 | matara
# Processing Record 8 of Set 26 | pangkalanbuun
# Processing Record 9 of Set 26 | zhezkazgan
# Processing Record 10 of Set 26 | pacific grove
# Processing Record 11 of Set 26 | senanga
# Processing Record 12 of Set 26 | bozeman
# Processing Record 13 of Set 26 | pocone
# Processing Record 14 of Set 26 | bogorodskoye
# Processing Record 15 of Set 26 | wajima
# Processing Record 16 of Set 26 | candido de abreu
# Processing Record 17 of Set 26 | vila
# Processing Record 18 of Set 26 | malyn
# Processing Record 19 of Set 26 | lago da pedra
# Processing Record 20 of Set 26 | arenapolis
# Processing Record 21 of Set 26 | nanakuli
# Processing Record 22 of Set 26 | ardakan
# Processing Record 23 of Set 26 | rolim de moura
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 26 | port keats
# Processing Record 25 of Set 26 | westport
# Processing Record 26 of Set 26 | saint-augustin
# Processing Record 27 of Set 26 | amurzet
# Processing Record 28 of Set 26 | darfield
# Processing Record 29 of Set 26 | jennings
# Processing Record 30 of Set 26 | belokurikha
# Processing Record 31 of Set 26 | sheltozero
# Processing Record 32 of Set 26 | olinda
# Processing Record 33 of Set 26 | slave lake
# Processing Record 34 of Set 26 | mount isa
# Processing Record 35 of Set 26 | port moresby
# Processing Record 36 of Set 26 | dubai
# Processing Record 37 of Set 26 | atyrau
# Processing Record 38 of Set 26 | sirjan
# Processing Record 39 of Set 26 | yarim
# Processing Record 40 of Set 26 | bubaque
# Processing Record 41 of Set 26 | mildura
# Processing Record 42 of Set 26 | gondanglegi
# Processing Record 43 of Set 26 | watertown
# Processing Record 44 of Set 26 | ponta delgada
# Processing Record 45 of Set 26 | weihe
# Processing Record 46 of Set 26 | finschhafen
# Processing Record 47 of Set 26 | saryozek
# Processing Record 48 of Set 26 | bowen
# Processing Record 49 of Set 26 | cumaribo
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 26 | karamay
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 27 | comodoro rivadavia
# Processing Record 2 of Set 27 | coihueco
# Processing Record 3 of Set 27 | nisia floresta
# Processing Record 4 of Set 27 | ramhormoz
# Processing Record 5 of Set 27 | port augusta
# Processing Record 6 of Set 27 | hit
# Processing Record 7 of Set 27 | jarjis
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 27 | san felipe
# Processing Record 9 of Set 27 | umm kaddadah
# Processing Record 10 of Set 27 | palmer
# Processing Record 11 of Set 27 | kozarmisleny
# Processing Record 12 of Set 27 | vanavara
# Processing Record 13 of Set 27 | pozoblanco
# Processing Record 14 of Set 27 | coxim
# Processing Record 15 of Set 27 | duz
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 27 | thanatpin
# Processing Record 17 of Set 27 | flin flon
# Processing Record 18 of Set 27 | kiama
# Processing Record 19 of Set 27 | viedma
# Processing Record 20 of Set 27 | sao miguel do oeste
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 27 | otuzco
# Processing Record 22 of Set 27 | thames
# Processing Record 23 of Set 27 | jiddah
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 27 | stonewall
# Processing Record 25 of Set 27 | nome
# Processing Record 26 of Set 27 | new plymouth
# Processing Record 27 of Set 27 | ahuimanu
# Processing Record 28 of Set 27 | sistranda
# Processing Record 29 of Set 27 | menongue
# Processing Record 30 of Set 27 | ancud
# Processing Record 31 of Set 27 | mlandizi
# Processing Record 32 of Set 27 | balsas
# Processing Record 33 of Set 27 | urumqi
# Processing Record 34 of Set 27 | san lazaro
# Processing Record 35 of Set 27 | nefteyugansk
# Processing Record 36 of Set 27 | safranbolu
# Processing Record 37 of Set 27 | puerto leguizamo
# Processing Record 38 of Set 27 | zvishavane
# Processing Record 39 of Set 27 | marquette
# Processing Record 40 of Set 27 | usinsk
# Processing Record 41 of Set 27 | sangmelima
# Processing Record 42 of Set 27 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 27 | ndiekro
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 27 | mergui
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 27 | aksha
# Processing Record 46 of Set 27 | beringovskiy
# Processing Record 47 of Set 27 | vestmannaeyjar
# Processing Record 48 of Set 27 | kyabram
# Processing Record 49 of Set 27 | edd
# Processing Record 50 of Set 27 | acapulco
# Processing Record 1 of Set 28 | pyatnitskoye
# Processing Record 2 of Set 28 | yenagoa
# Processing Record 3 of Set 28 | palestine
# Processing Record 4 of Set 28 | dingle
# Processing Record 5 of Set 28 | peregu mare
# Processing Record 6 of Set 28 | malbork
# Processing Record 7 of Set 28 | saint-joseph
# Processing Record 8 of Set 28 | nagaoka
# Processing Record 9 of Set 28 | kongwa
# Processing Record 10 of Set 28 | esmeraldas
# Processing Record 11 of Set 28 | yima
# Processing Record 12 of Set 28 | tessalit
# Processing Record 13 of Set 28 | gigmoto
# Processing Record 14 of Set 28 | colac
# Processing Record 15 of Set 28 | ulladulla
# Processing Record 16 of Set 28 | tommot
# Processing Record 17 of Set 28 | vadinsk
# Processing Record 18 of Set 28 | marsa matruh
# Processing Record 19 of Set 28 | milingimbi
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 28 | paita
# Processing Record 21 of Set 28 | imbituba
# Processing Record 22 of Set 28 | garden city
# Processing Record 23 of Set 28 | castanos
# Processing Record 24 of Set 28 | kalmanka
# Processing Record 25 of Set 28 | necochea
# Processing Record 26 of Set 28 | le vauclin
# Processing Record 27 of Set 28 | lowestoft
# Processing Record 28 of Set 28 | cockburn harbour
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 28 | daloa
# Processing Record 30 of Set 28 | tandil
# Processing Record 31 of Set 28 | cairns
# Processing Record 32 of Set 28 | port hedland
# Processing Record 33 of Set 28 | zilair
# Processing Record 34 of Set 28 | camacupa
# Processing Record 35 of Set 28 | kaeo
# Processing Record 36 of Set 28 | lakatoro
# Processing Record 37 of Set 28 | waipawa
# Processing Record 38 of Set 28 | soyo
# Processing Record 39 of Set 28 | podor
# Processing Record 40 of Set 28 | nuuk
# Processing Record 41 of Set 28 | shenjiamen
# Processing Record 42 of Set 28 | ler
# Processing Record 43 of Set 28 | chardara
# Processing Record 44 of Set 28 | kailua
# Processing Record 45 of Set 28 | satun
# Processing Record 46 of Set 28 | kafanchan
# Processing Record 47 of Set 28 | arys
# Processing Record 48 of Set 28 | vulcanesti
# Processing Record 49 of Set 28 | sidi ali
# Processing Record 50 of Set 28 | labuhan
# Processing Record 1 of Set 29 | araouane
# Processing Record 2 of Set 29 | semirom
# Processing Record 3 of Set 29 | wetzlar
# Processing Record 4 of Set 29 | wilmington island
# Processing Record 5 of Set 29 | stryn
# Processing Record 6 of Set 29 | chengkung
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 29 | banda aceh
# Processing Record 8 of Set 29 | manzil tamim
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 29 | alabaster
# Processing Record 10 of Set 29 | taman
# Processing Record 11 of Set 29 | boa vista
# Processing Record 12 of Set 29 | preobrazheniye
# Processing Record 13 of Set 29 | los llanos de aridane
# Processing Record 14 of Set 29 | monopoli
# Processing Record 15 of Set 29 | ekimchan
# Processing Record 16 of Set 29 | ban dung
# Processing Record 17 of Set 29 | lavumisa
# Processing Record 18 of Set 29 | nizhniy tsasuchey
# Processing Record 19 of Set 29 | cholan
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 29 | patamundai
# Processing Record 21 of Set 29 | bang saphan
# Processing Record 22 of Set 29 | manado
# Processing Record 23 of Set 29 | wuwei
# Processing Record 24 of Set 29 | karema
# Processing Record 25 of Set 29 | seydi
# Processing Record 26 of Set 29 | kismayo
# Processing Record 27 of Set 29 | diu
# Processing Record 28 of Set 29 | katobu
# Processing Record 29 of Set 29 | calamar
# Processing Record 30 of Set 29 | antibes
# Processing Record 31 of Set 29 | mogadishu
# Processing Record 32 of Set 29 | hisor
# Processing Record 33 of Set 29 | havre de grace
# Processing Record 34 of Set 29 | maceio
# Processing Record 35 of Set 29 | voka
# Processing Record 36 of Set 29 | tagbac
# Processing Record 37 of Set 29 | mirnyy
# Processing Record 38 of Set 29 | caravelas
# Processing Record 39 of Set 29 | nchelenge
# Processing Record 40 of Set 29 | troitsko-pechorsk
# Processing Record 41 of Set 29 | abnub
# Processing Record 42 of Set 29 | alekseyevsk
# Processing Record 43 of Set 29 | bijar
# Processing Record 44 of Set 29 | kamaishi
# Processing Record 45 of Set 29 | rio grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': -52.0986, 'lat': -32.035},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 70,
#   'feels_like': 68.31,
#   'temp_min': 70,
#   'temp_max': 70,
#   'pressure': 1015,
#   'humidity': 76},
#  'visibility': 10000,
#  'wind': {'speed': 10.22, 'deg': 100},
#  'clouds': {'all': 0},
#  'dt': 1612744474,
#  'sys': {'type': 3,
#   'id': 2020865,
#   'country': 'BR',
#   'sunrise': 1612688359,
#   'sunset': 1612736751},
#  'timezone': -10800,
#  'id': 3451138,
#  'name': 'Rio Grande',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bredasdorp      ZA -34.5322   20.0403     59.00        77           8
# 1       Ushuaia      AR -54.8000  -68.3000     51.80        82          75
# 2         Nebbi      UG   2.4783   31.0889     69.67        27         100
# 3      Sisimiut      GL  66.9395  -53.6735     24.67        79           2
# 4          Emba      KZ  48.8264   58.1442     -5.13        90          30
# 5   Yellowknife      CA  62.4560 -114.3525    -32.80        68          40
# 6       Mataura      NZ -46.1927  168.8643     73.42        42         100
# 7         Vaini      TO -21.2000 -175.2000     77.00        94          90
# 8       Merauke      ID  -8.4667  140.3333     84.88        73          43
# 9  Puerto Ayora      EC  -0.7393  -90.3518     77.00        96         100
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1       10.36       broken clouds
# 2        4.74     overcast clouds
# 3       17.05           clear sky
# 4       12.53    scattered clouds
# 5        8.05    scattered clouds
# 6        3.15     overcast clouds
# 7       16.11       moderate rain
# 8       11.79    scattered clouds
# 9        1.99          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
