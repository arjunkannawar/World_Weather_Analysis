# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1db5d0559ca44b042fc0ee3e3fdac1a0

# %%
# Create an empty list to hold the weather data.
city_data = []
city_data_new_df = [] #Creating an empty Data Frame to hold the array of dcitionaries into a data frame.
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        #city_current_description = city_weather["weather"]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        #city_current_description = city_weather["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print (e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | east london
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 15 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 15 | george
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 15 | fairbanks
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 15 | pindiga
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 15 | mataura
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 15 | cape town
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 15 | rikitea
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 15 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 15 | khingansk
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 15 | saint-philippe
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 15 | punta arenas
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 15 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 15 | hami
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 15 | jamestown
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 15 | dingle
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 15 | albany
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 15 | vao
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 15 | ulladulla
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 15 | victoria
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 15 | charters towers
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 15 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 15 | tevaitoa
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 15 | mahebourg
# Processing Record 25 of Set 15 | panzhihua
# Processing Record 26 of Set 15 | hudson bay
# Processing Record 27 of Set 15 | kaeo
# Processing Record 28 of Set 15 | hobart
# Processing Record 29 of Set 15 | uray
# Processing Record 30 of Set 15 | barrow
# Processing Record 31 of Set 15 | ribeira grande
# Processing Record 32 of Set 15 | leningradskiy
# Processing Record 33 of Set 15 | dikson
# Processing Record 34 of Set 15 | mar del plata
# Processing Record 35 of Set 15 | panama city
# Processing Record 36 of Set 15 | bluff
# Processing Record 37 of Set 15 | santa rosa
# Processing Record 38 of Set 15 | pemba
# Processing Record 39 of Set 15 | bredasdorp
# Processing Record 40 of Set 15 | vryburg
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 15 | cidreira
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 15 | puerto ayora
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 15 | hellvik
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 15 | husavik
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 15 | paita
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 15 | avarua
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 15 | deputatskiy
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 15 | tiksi
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 15 | pevek
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 15 | port elizabeth
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 16 | carnarvon
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 16 | kruisfontein
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 16 | salalah
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 16 | letlhakeng
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 16 | alofi
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 16 | matay
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 16 | parrita
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 16 | port lincoln
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 16 | milkovo
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 16 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 16 | valdivia
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 16 | mangaldai
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 16 | busselton
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 16 | saskylakh
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 16 | aljezur
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 16 | khatanga
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 16 | hasaki
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 16 | ponta do sol
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 16 | pacific grove
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 16 | ust-kuyga
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 16 | kodiak
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 16 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 16 | saint-augustin
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 16 | ushuaia
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 16 | lokosovo
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 16 | tarudant
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 16 | bam
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 16 | nouadhibou
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 16 | hilo
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 16 | baruun-urt
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 16 | atuona
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 16 | ancud
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 16 | tianpeng
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 16 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 16 | tasiilaq
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 16 | gornyye klyuchi
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 16 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 16 | kaitangata
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 16 | praia
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 16 | dargaville
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 16 | hithadhoo
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 16 | butaritari
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 16 | north bend
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 16 | longyearbyen
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 16 | reitz
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 16 | chernyshevskiy
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 16 | elk point
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 16 | berlevag
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 16 | paracuru
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 16 | provideniya
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 17 | yellowknife
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 17 | yairipok
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 17 | port augusta
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 17 | dawei
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 17 | kloulklubed
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 17 | umea
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 17 | harpanahalli
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 17 | adrar
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 17 | westport
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 17 | brae
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 17 | saint george
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 17 | talnakh
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 17 | norman wells
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 17 | dombarovskiy
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 17 | sao filipe
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 17 | evensk
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 17 | nguiu
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 17 | durant
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 17 | pochutla
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 17 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 17 | oriximina
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 17 | bambous virieux
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 17 | nhulunbuy
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 17 | dehloran
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 17 | trofors
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 17 | narsaq
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 17 | hermanus
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 17 | huazolotitlan
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 17 | andra
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 17 | new norfolk
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 17 | grindavik
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 17 | kabinda
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 17 | doka
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 17 | aushiger
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 17 | chenzhou
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 17 | manoel urbano
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 17 | jinchengjiang
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 17 | arraial do cabo
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 17 | bathsheba
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 17 | polunochnoye
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 17 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 17 | stockach
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 17 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 17 | sambava
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 17 | alyangula
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 17 | beringovskiy
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 17 | honiara
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 17 | kavaratti
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 17 | alcacer do sal
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 17 | nikolskoye
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 18 | zunyi
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 18 | northam
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 18 | meridian
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 18 | loutra
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 18 | cascais
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 18 | ilulissat
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 18 | puerto baquerizo moreno
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 18 | douglas
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 18 | sechenovo
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 18 | kapaa
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 18 | iracoubo
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 18 | vieux-habitants
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 18 | vila franca do campo
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 18 | ocos
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 18 | okhotsk
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 18 | severo-kurilsk
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 18 | vaini
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 18 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 18 | tuatapere
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 18 | dunedin
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 18 | aklavik
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 18 | canutama
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 18 | riyadh
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 18 | chuy
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 18 | abu samrah
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 18 | abilene
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 18 | taltal
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 18 | muros
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 18 | atar
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 18 | mehamn
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 18 | nanortalik
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 18 | faanui
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 18 | olinda
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 18 | wainwright
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 18 | borogontsy
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 18 | port alfred
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 18 | itaocara
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 18 | ulkan
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 18 | kindberg
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 18 | thompson
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 18 | esso
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 18 | san patricio
# Processing Record 43 of Set 18 | laguna
# Processing Record 44 of Set 18 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 18 | udachnyy
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 18 | kavieng
# Processing Record 47 of Set 18 | mount gambier
# Processing Record 48 of Set 18 | saldanha
# Processing Record 49 of Set 18 | xiuyan
# Processing Record 50 of Set 18 | okato
# Processing Record 1 of Set 19 | coromandel
# Processing Record 2 of Set 19 | lucea
# Processing Record 3 of Set 19 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 19 | deniliquin
# Processing Record 5 of Set 19 | labuhan
# Processing Record 6 of Set 19 | chokurdakh
# Processing Record 7 of Set 19 | buala
# Processing Record 8 of Set 19 | georgetown
# Processing Record 9 of Set 19 | sorland
# Processing Record 10 of Set 19 | sheksna
# Processing Record 11 of Set 19 | saint-francois
# Processing Record 12 of Set 19 | clyde river
# Processing Record 13 of Set 19 | henties bay
# Processing Record 14 of Set 19 | itarema
# Processing Record 15 of Set 19 | nome
# Processing Record 16 of Set 19 | najran
# Processing Record 17 of Set 19 | lasa
# Processing Record 18 of Set 19 | mnogovershinnyy
# Processing Record 19 of Set 19 | kamina
# Processing Record 20 of Set 19 | biak
# Processing Record 21 of Set 19 | isangel
# Processing Record 22 of Set 19 | lethem
# Processing Record 23 of Set 19 | hamilton
# Processing Record 24 of Set 19 | araouane
# Processing Record 25 of Set 19 | klaksvik
# Processing Record 26 of Set 19 | bonthe
# Processing Record 27 of Set 19 | mananara
# Processing Record 28 of Set 19 | bertoua
# Processing Record 29 of Set 19 | harigue
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 19 | bengkulu
# Processing Record 31 of Set 19 | vardo
# Processing Record 32 of Set 19 | marsaxlokk
# Processing Record 33 of Set 19 | chute-aux-outardes
# Processing Record 34 of Set 19 | meadow lake
# Processing Record 35 of Set 19 | tananger
# Processing Record 36 of Set 19 | enkhuizen
# Processing Record 37 of Set 19 | castro
# Processing Record 38 of Set 19 | youkounkoun
# Processing Record 39 of Set 19 | fort nelson
# Processing Record 40 of Set 19 | katobu
# Processing Record 41 of Set 19 | saint-joseph
# Processing Record 42 of Set 19 | iberia
# Processing Record 43 of Set 19 | lakes entrance
# Processing Record 44 of Set 19 | kastamonu
# Processing Record 45 of Set 19 | coihaique
# Processing Record 46 of Set 19 | limulunga
# Processing Record 47 of Set 19 | kilindoni
# Processing Record 48 of Set 19 | ilfracombe
# Processing Record 49 of Set 19 | kunyang
# Processing Record 50 of Set 19 | savannah bight
# Processing Record 1 of Set 20 | sechura
# Processing Record 2 of Set 20 | tuktoyaktuk
# Processing Record 3 of Set 20 | suez
# Processing Record 4 of Set 20 | lazaro cardenas
# Processing Record 5 of Set 20 | cherskiy
# Processing Record 6 of Set 20 | nyrob
# Processing Record 7 of Set 20 | arlit
# Processing Record 8 of Set 20 | horsham
# Processing Record 9 of Set 20 | qaanaaq
# Processing Record 10 of Set 20 | shingu
# Processing Record 11 of Set 20 | banda aceh
# Processing Record 12 of Set 20 | margate
# Processing Record 13 of Set 20 | torbay
# Processing Record 14 of Set 20 | boddam
# Processing Record 15 of Set 20 | geraldton
# Processing Record 16 of Set 20 | jieshi
# Processing Record 17 of Set 20 | chulman
# Processing Record 18 of Set 20 | iqaluit
# Processing Record 19 of Set 20 | fonte boa
# Processing Record 20 of Set 20 | ituni
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 20 | san andres
# Processing Record 22 of Set 20 | quatre cocos
# Processing Record 23 of Set 20 | ketchikan
# Processing Record 24 of Set 20 | barranca
# Processing Record 25 of Set 20 | namatanai
# Processing Record 26 of Set 20 | kruje
# Processing Record 27 of Set 20 | lebu
# Processing Record 28 of Set 20 | yeppoon
# Processing Record 29 of Set 20 | banning
# Processing Record 30 of Set 20 | port-gentil
# Processing Record 31 of Set 20 | lagoa
# Processing Record 32 of Set 20 | kahului
# Processing Record 33 of Set 20 | constitucion
# Processing Record 34 of Set 20 | amurzet
# Processing Record 35 of Set 20 | kanniyakumari
# Processing Record 36 of Set 20 | domoni
# Processing Record 37 of Set 20 | rocha
# Processing Record 38 of Set 20 | camopi
# Processing Record 39 of Set 20 | sitka
# Processing Record 40 of Set 20 | pierre
# Processing Record 41 of Set 20 | ondorhaan
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 20 | san francisco de becerra
# Processing Record 43 of Set 20 | okulovka
# Processing Record 44 of Set 20 | whitianga
# Processing Record 45 of Set 20 | miri
# Processing Record 46 of Set 20 | shimoda
# Processing Record 47 of Set 20 | csabrendek
# Processing Record 48 of Set 20 | tikhvin
# Processing Record 49 of Set 20 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 20 | markova
# Processing Record 1 of Set 21 | lavrentiya
# Processing Record 2 of Set 21 | bethel
# Processing Record 3 of Set 21 | dabat
# Processing Record 4 of Set 21 | san policarpo
# Processing Record 5 of Set 21 | takanabe
# Processing Record 6 of Set 21 | fortuna
# Processing Record 7 of Set 21 | channel-port aux basques
# Processing Record 8 of Set 21 | roma
# Processing Record 9 of Set 21 | astoria
# Processing Record 10 of Set 21 | sawtell
# Processing Record 11 of Set 21 | srednekolymsk
# Processing Record 12 of Set 21 | kaniama
# Processing Record 13 of Set 21 | xining
# Processing Record 14 of Set 21 | katav-ivanovsk
# Processing Record 15 of Set 21 | abasolo
# Processing Record 16 of Set 21 | hays
# Processing Record 17 of Set 21 | kirovsk
# Processing Record 18 of Set 21 | atikokan
# Processing Record 19 of Set 21 | zonguldak
# Processing Record 20 of Set 21 | dongsheng
# Processing Record 21 of Set 21 | broken hill
# Processing Record 22 of Set 21 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 21 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 21 | elizabeth city
# Processing Record 25 of Set 21 | igarka
# Processing Record 26 of Set 21 | pedro ii
# Processing Record 27 of Set 21 | buin
# Processing Record 28 of Set 21 | cayenne
# Processing Record 29 of Set 21 | airai
# Processing Record 30 of Set 21 | swellendam
# Processing Record 31 of Set 21 | pundaguitan
# Processing Record 32 of Set 21 | zhigansk
# Processing Record 33 of Set 21 | vaitape
# Processing Record 34 of Set 21 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 21 | ipixuna
# Processing Record 36 of Set 21 | luderitz
# Processing Record 37 of Set 21 | necochea
# Processing Record 38 of Set 21 | villa carlos paz
# Processing Record 39 of Set 21 | sabang
# Processing Record 40 of Set 21 | ahuimanu
# Processing Record 41 of Set 21 | alice springs
# Processing Record 42 of Set 21 | vostochnyy
# Processing Record 43 of Set 21 | pimentel
# Processing Record 44 of Set 21 | nueva imperial
# Processing Record 45 of Set 21 | lillooet
# Processing Record 46 of Set 21 | mayumba
# Processing Record 47 of Set 21 | abu kamal
# Processing Record 48 of Set 21 | temple
# Processing Record 49 of Set 21 | karaul
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 21 | beloha
# Processing Record 1 of Set 22 | kieta
# Processing Record 2 of Set 22 | tommot
# Processing Record 3 of Set 22 | esperance
# Processing Record 4 of Set 22 | palana
# Processing Record 5 of Set 22 | aromashevo
# Processing Record 6 of Set 22 | muswellbrook
# Processing Record 7 of Set 22 | grand bank
# Processing Record 8 of Set 22 | coquimbo
# Processing Record 9 of Set 22 | padang
# Processing Record 10 of Set 22 | bjorkelangen
# Processing Record 11 of Set 22 | virginia beach
# Processing Record 12 of Set 22 | pokrovsk
# Processing Record 13 of Set 22 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 22 | francisco beltrao
# Processing Record 15 of Set 22 | sinnamary
# Processing Record 16 of Set 22 | manhattan
# Processing Record 17 of Set 22 | kushima
# Processing Record 18 of Set 22 | santa cruz
# Processing Record 19 of Set 22 | kiunga
# Processing Record 20 of Set 22 | moba
# Processing Record 21 of Set 22 | zeya
# Processing Record 22 of Set 22 | baghdad
# Processing Record 23 of Set 22 | dibulla
# Processing Record 24 of Set 22 | falam
# Processing Record 25 of Set 22 | katsuura
# Processing Record 26 of Set 22 | vestmannaeyjar
# Processing Record 27 of Set 22 | hay river
# Processing Record 28 of Set 22 | nandigama
# Processing Record 29 of Set 22 | mudanjiang
# Processing Record 30 of Set 22 | cabo san lucas
# Processing Record 31 of Set 22 | sioux lookout
# Processing Record 32 of Set 22 | codo
# Processing Record 33 of Set 22 | antsohihy
# Processing Record 34 of Set 22 | luwuk
# Processing Record 35 of Set 22 | chumikan
# Processing Record 36 of Set 22 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 22 | port keats
# Processing Record 38 of Set 22 | yenagoa
# Processing Record 39 of Set 22 | grand gaube
# Processing Record 40 of Set 22 | tazovskiy
# Processing Record 41 of Set 22 | mwinilunga
# Processing Record 42 of Set 22 | dhidhdhoo
# Processing Record 43 of Set 22 | sao gabriel da cachoeira
# Processing Record 44 of Set 22 | dosso
# Processing Record 45 of Set 22 | houma
# Processing Record 46 of Set 22 | simao
# Processing Record 47 of Set 22 | yumbel
# Processing Record 48 of Set 22 | bose
# Processing Record 49 of Set 22 | bilibino
# Processing Record 50 of Set 22 | galiwinku
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 23 | te anau
# Processing Record 2 of Set 23 | ler
# Processing Record 3 of Set 23 | herat
# Processing Record 4 of Set 23 | santa fe
# Processing Record 5 of Set 23 | tombouctou
# Processing Record 6 of Set 23 | seoul
# Processing Record 7 of Set 23 | sterling
# Processing Record 8 of Set 23 | la ligua
# Processing Record 9 of Set 23 | ngukurr
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 23 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 23 | san isidro
# Processing Record 12 of Set 23 | roura
# Processing Record 13 of Set 23 | aksu
# Processing Record 14 of Set 23 | calama
# Processing Record 15 of Set 23 | tiarei
# Processing Record 16 of Set 23 | batagay
# Processing Record 17 of Set 23 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 23 | rawson
# Processing Record 19 of Set 23 | svetlogorsk
# Processing Record 20 of Set 23 | mastic beach
# Processing Record 21 of Set 23 | broome
# Processing Record 22 of Set 23 | yar-sale
# Processing Record 23 of Set 23 | manono
# Processing Record 24 of Set 23 | loikaw
# Processing Record 25 of Set 23 | solwezi
# Processing Record 26 of Set 23 | ngunguru
# Processing Record 27 of Set 23 | royan
# Processing Record 28 of Set 23 | hushitai
# Processing Record 29 of Set 23 | manzanillo
# Processing Record 30 of Set 23 | mackenzie
# Processing Record 31 of Set 23 | paamiut
# Processing Record 32 of Set 23 | andros
# Processing Record 33 of Set 23 | asau
# Processing Record 34 of Set 23 | vostok
# Processing Record 35 of Set 23 | hammerfest
# Processing Record 36 of Set 23 | pedasi
# Processing Record 37 of Set 23 | porto novo
# Processing Record 38 of Set 23 | egvekinot
# Processing Record 39 of Set 23 | sur
# Processing Record 40 of Set 23 | cobija
# Processing Record 41 of Set 23 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 23 | ampanihy
# Processing Record 43 of Set 23 | isabela
# Processing Record 44 of Set 23 | kaitong
# Processing Record 45 of Set 23 | barbar
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 23 | sungaipenuh
# Processing Record 47 of Set 23 | champerico
# Processing Record 48 of Set 23 | upernavik
# Processing Record 49 of Set 23 | saint-pierre
# Processing Record 50 of Set 23 | lata
# Processing Record 1 of Set 24 | nylstroom
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 24 | marzuq
# Processing Record 3 of Set 24 | gimli
# Processing Record 4 of Set 24 | sangar
# Processing Record 5 of Set 24 | sirnak
# Processing Record 6 of Set 24 | jales
# Processing Record 7 of Set 24 | marakkanam
# Processing Record 8 of Set 24 | half moon bay
# Processing Record 9 of Set 24 | souillac
# Processing Record 10 of Set 24 | corinth
# Processing Record 11 of Set 24 | uenohara
# Processing Record 12 of Set 24 | nchelenge
# Processing Record 13 of Set 24 | thessalon
# Processing Record 14 of Set 24 | tongchuan
# Processing Record 15 of Set 24 | chake chake
# Processing Record 16 of Set 24 | college
# Processing Record 17 of Set 24 | kivertsi
# Processing Record 18 of Set 24 | beyneu
# Processing Record 19 of Set 24 | leshukonskoye
# Processing Record 20 of Set 24 | saint anthony
# Processing Record 21 of Set 24 | guozhen
# Processing Record 22 of Set 24 | bol
# Processing Record 23 of Set 24 | dombas
# Processing Record 24 of Set 24 | mareeba
# Processing Record 25 of Set 24 | walvis bay
# Processing Record 26 of Set 24 | valle nacional
# Processing Record 27 of Set 24 | tezu
# Processing Record 28 of Set 24 | quesnel
# Processing Record 29 of Set 24 | jalu
# Processing Record 30 of Set 24 | bandar-e anzali
# Processing Record 31 of Set 24 | maumere
# Processing Record 32 of Set 24 | xinqing
# Processing Record 33 of Set 24 | panorama
# Processing Record 34 of Set 24 | kodinsk
# Processing Record 35 of Set 24 | malanje
# Processing Record 36 of Set 24 | makat
# Processing Record 37 of Set 24 | chalon-sur-saone
# Processing Record 38 of Set 24 | cardston
# Processing Record 39 of Set 24 | shirokiy
# Processing Record 40 of Set 24 | bonavista
# Processing Record 41 of Set 24 | samalaeulu
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 24 | acarau
# Processing Record 43 of Set 24 | koboko
# Processing Record 44 of Set 24 | mana
# Processing Record 45 of Set 24 | dunmore town
# Processing Record 46 of Set 24 | manacapuru
# Processing Record 47 of Set 24 | dzhebariki-khaya
# Processing Record 48 of Set 24 | petauke
# Processing Record 49 of Set 24 | novobirilyussy
# Processing Record 50 of Set 24 | a
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 25 | penzance
# Processing Record 2 of Set 25 | zhanaozen
# Processing Record 3 of Set 25 | namibe
# Processing Record 4 of Set 25 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 25 | yingcheng
# Processing Record 6 of Set 25 | zdvinsk
# Processing Record 7 of Set 25 | glotovka
# Processing Record 8 of Set 25 | ust-nera
# Processing Record 9 of Set 25 | kapoeta
# Processing Record 10 of Set 25 | poum
# Processing Record 11 of Set 25 | mwense
# Processing Record 12 of Set 25 | aybak
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 25 | kambove
# Processing Record 14 of Set 25 | quelimane
# Processing Record 15 of Set 25 | yulara
# Processing Record 16 of Set 25 | severnyy
# Processing Record 17 of Set 25 | impfondo
# Processing Record 18 of Set 25 | arman
# Processing Record 19 of Set 25 | vila velha
# Processing Record 20 of Set 25 | bulgan
# Processing Record 21 of Set 25 | remedios
# Processing Record 22 of Set 25 | taksimo
# Processing Record 23 of Set 25 | keetmanshoop
# Processing Record 24 of Set 25 | kununurra
# Processing Record 25 of Set 25 | zuwarah
# Processing Record 26 of Set 25 | labuan
# Processing Record 27 of Set 25 | mecca
# Processing Record 28 of Set 25 | aktau
# Processing Record 29 of Set 25 | srandakan
# Processing Record 30 of Set 25 | muskegon
# Processing Record 31 of Set 25 | camana
# Processing Record 32 of Set 25 | gainesville
# Processing Record 33 of Set 25 | oussouye
# Processing Record 34 of Set 25 | viedma
# Processing Record 35 of Set 25 | taunggyi
# Processing Record 36 of Set 25 | agirish
# Processing Record 37 of Set 25 | tura
# Processing Record 38 of Set 25 | homer
# Processing Record 39 of Set 25 | buncrana
# Processing Record 40 of Set 25 | ferreiras
# Processing Record 41 of Set 25 | gamboma
# Processing Record 42 of Set 25 | romans-sur-isere
# Processing Record 43 of Set 25 | gold coast
# Processing Record 44 of Set 25 | polis
# Processing Record 45 of Set 25 | matamoros
# Processing Record 46 of Set 25 | lebedinyy
# Processing Record 47 of Set 25 | mokrous
# Processing Record 48 of Set 25 | bukachacha
# Processing Record 49 of Set 25 | mayo
# Processing Record 50 of Set 25 | komsomolskiy
# Processing Record 1 of Set 26 | praia da vitoria
# Processing Record 2 of Set 26 | timizart
# Processing Record 3 of Set 26 | shubarshi
# Processing Record 4 of Set 26 | usinsk
# Processing Record 5 of Set 26 | tarata
# Processing Record 6 of Set 26 | bosaso
# Processing Record 7 of Set 26 | tabas
# Processing Record 8 of Set 26 | liverpool
# Processing Record 9 of Set 26 | cap malheureux
# Processing Record 10 of Set 26 | nizhnekamsk
# Processing Record 11 of Set 26 | deggendorf
# Processing Record 12 of Set 26 | micheweni
# Processing Record 13 of Set 26 | vanimo
# Processing Record 14 of Set 26 | melur
# Processing Record 15 of Set 26 | tateyama
# Processing Record 16 of Set 26 | mariental
# Processing Record 17 of Set 26 | oktyabrskoye
# Processing Record 18 of Set 26 | xapuri
# Processing Record 19 of Set 26 | kenora
# Processing Record 20 of Set 26 | touros
# Processing Record 21 of Set 26 | el wasta
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 26 | oudtshoorn
# Processing Record 23 of Set 26 | visnes
# Processing Record 24 of Set 26 | coruripe
# Processing Record 25 of Set 26 | brigantine
# Processing Record 26 of Set 26 | promysla
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 26 | sidi bu zayd
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 26 | turayf
# Processing Record 29 of Set 26 | nadym
# Processing Record 30 of Set 26 | chepareria
# Processing Record 31 of Set 26 | alice town
# Processing Record 32 of Set 26 | whitehorse
# Processing Record 33 of Set 26 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 26 | portage
# Processing Record 35 of Set 26 | plerin
# Processing Record 36 of Set 26 | plettenberg bay
# Processing Record 37 of Set 26 | vestmanna
# Processing Record 38 of Set 26 | samana
# Processing Record 39 of Set 26 | matara
# Processing Record 40 of Set 26 | dibaya
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 26 | kurumkan
# Processing Record 42 of Set 26 | richards bay
# Processing Record 43 of Set 26 | bereda
# Processing Record 44 of Set 26 | flinders
# Processing Record 45 of Set 26 | san cristobal
# Processing Record 46 of Set 26 | nosy varika
# Processing Record 47 of Set 26 | nuuk
# Processing Record 48 of Set 26 | satitoa
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 26 | south lake tahoe
# Processing Record 50 of Set 26 | dubuque
# Processing Record 1 of Set 27 | arboletes
# Processing Record 2 of Set 27 | west wendover
# Processing Record 3 of Set 27 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 27 | uthai thani
# Processing Record 5 of Set 27 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 27 | litovko
# Processing Record 7 of Set 27 | pangkalanbuun
# Processing Record 8 of Set 27 | hazorasp
# Processing Record 9 of Set 27 | miramar
# Processing Record 10 of Set 27 | kirakira
# Processing Record 11 of Set 27 | ottawa
# Processing Record 12 of Set 27 | akyab
# Processing Record 13 of Set 27 | karratha
# Processing Record 14 of Set 27 | kabugao
# Processing Record 15 of Set 27 | seymchan
# Processing Record 16 of Set 27 | sultanpur
# Processing Record 17 of Set 27 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 27 | jumla
# Processing Record 19 of Set 27 | aykhal
# Processing Record 20 of Set 27 | port hardy
# Processing Record 21 of Set 27 | katunki
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 27 | port blair
# Processing Record 23 of Set 27 | lorengau
# Processing Record 24 of Set 27 | grand-santi
# Processing Record 25 of Set 27 | fochville
# Processing Record 26 of Set 27 | de aar
# Processing Record 27 of Set 27 | presidencia roque saenz pena
# Processing Record 28 of Set 27 | zhemchuzhnyy
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 27 | tres picos
# Processing Record 30 of Set 27 | orlik
# Processing Record 31 of Set 27 | mastung
# Processing Record 32 of Set 27 | hofn
# Processing Record 33 of Set 27 | shostka
# Processing Record 34 of Set 27 | duluth
# Processing Record 35 of Set 27 | ilukste
# Processing Record 36 of Set 27 | ruatoria
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 27 | ust-kamchatsk
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 27 | luganville
# Processing Record 39 of Set 27 | uruzgan
# Processing Record 40 of Set 27 | cockburn town
# Processing Record 41 of Set 27 | puri
# Processing Record 42 of Set 27 | pisco
# Processing Record 43 of Set 27 | tonj
# Processing Record 44 of Set 27 | qasigiannguit
# Processing Record 45 of Set 27 | mindelo
# Processing Record 46 of Set 27 | andros town
# Processing Record 47 of Set 27 | port-cartier
# Processing Record 48 of Set 27 | peniche
# Processing Record 49 of Set 27 | olafsvik
# Processing Record 50 of Set 27 | tulum
# Processing Record 1 of Set 28 | lompoc
# Processing Record 2 of Set 28 | iquitos
# Processing Record 3 of Set 28 | hambantota
# Processing Record 4 of Set 28 | nkan
# Processing Record 5 of Set 28 | bara
# Processing Record 6 of Set 28 | cumaribo
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 28 | rundu
# Processing Record 8 of Set 28 | autazes
# Processing Record 9 of Set 28 | noumea
# Processing Record 10 of Set 28 | pinheiro
# Processing Record 11 of Set 28 | nemuro
# Processing Record 12 of Set 28 | labytnangi
# Processing Record 13 of Set 28 | hakvik
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 28 | suntar
# Processing Record 15 of Set 28 | cartagena
# Processing Record 16 of Set 28 | zhezkazgan
# Processing Record 17 of Set 28 | nizhniy kuranakh
# Processing Record 18 of Set 28 | batemans bay
# Processing Record 19 of Set 28 | comodoro rivadavia
# Processing Record 20 of Set 28 | potsdam
# Processing Record 21 of Set 28 | buenos aires
# Processing Record 22 of Set 28 | bury saint edmunds
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 28 | guerrero negro
# Processing Record 24 of Set 28 | surt
# Processing Record 25 of Set 28 | caravelas
# Processing Record 26 of Set 28 | cherat
# Processing Record 27 of Set 28 | kingman
# Processing Record 28 of Set 28 | codrington
# Processing Record 29 of Set 28 | san vicente
# Processing Record 30 of Set 28 | hualmay
# Processing Record 31 of Set 28 | nenjiang
# Processing Record 32 of Set 28 | marienburg
# Processing Record 33 of Set 28 | sao sebastiao
# Processing Record 34 of Set 28 | roald
# Processing Record 35 of Set 28 | ambulu
# Processing Record 36 of Set 28 | samarai
# Processing Record 37 of Set 28 | tanout
# Processing Record 38 of Set 28 | milverton
# Processing Record 39 of Set 28 | ambon
# Processing Record 40 of Set 28 | meyungs
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 28 | chiredzi
# Processing Record 42 of Set 28 | ballina
# Processing Record 43 of Set 28 | bullhead city
# Processing Record 44 of Set 28 | naugarzan
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 28 | gumdag
# Processing Record 46 of Set 28 | kroya
# Processing Record 47 of Set 28 | mabaruma
# Processing Record 48 of Set 28 | opunake
# Processing Record 49 of Set 28 | meulaboh
# Processing Record 50 of Set 28 | faya
# Processing Record 1 of Set 29 | manokwari
# Processing Record 2 of Set 29 | utiroa
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 29 | novopokrovka
# Processing Record 4 of Set 29 | nanakuli
# Processing Record 5 of Set 29 | boa vista
# Processing Record 6 of Set 29 | santa cruz de la palma
# Processing Record 7 of Set 29 | nantucket
# Processing Record 8 of Set 29 | basco
# Processing Record 9 of Set 29 | copiapo
# Processing Record 10 of Set 29 | waddan
# Processing Record 11 of Set 29 | palmer
# Processing Record 12 of Set 29 | bastia
# Processing Record 13 of Set 29 | bella union
# Processing Record 14 of Set 29 | fengzhen
# Processing Record 15 of Set 29 | baykit
# Processing Record 16 of Set 29 | halalo
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 29 | beibei
# Processing Record 18 of Set 29 | alim
# Processing Record 19 of Set 29 | qaqortoq
# Processing Record 20 of Set 29 | port shepstone
# Processing Record 21 of Set 29 | mazatlan
# Processing Record 22 of Set 29 | serov
# Processing Record 23 of Set 29 | santa maria
# Processing Record 24 of Set 29 | salinopolis
# Processing Record 25 of Set 29 | quchan
# Processing Record 26 of Set 29 | ishigaki
# Processing Record 27 of Set 29 | tarakan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 117.6333, 'lat': 3.3},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 78.84,
#   'feels_like': 84.24,
#   'temp_min': 78.84,
#   'temp_max': 78.84,
#   'pressure': 1008,
#   'humidity': 84,
#   'sea_level': 1008,
#   'grnd_level': 1003},
#  'visibility': 10000,
#  'wind': {'speed': 7.36, 'deg': 342},
#  'clouds': {'all': 100},
#  'dt': 1612732101,
#  'sys': {'country': 'ID', 'sunrise': 1612736627, 'sunset': 1612779815},
#  'timezone': 28800,
#  'id': 1624725,
#  'name': 'Tarakan',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mahebourg      MU -20.4081   57.7000     80.60        78          75
# 1       Panzhihua      CN  26.5851  101.7128     46.99        65          88
# 2      Hudson Bay      CA  52.8500 -102.3842    -22.40        80          43
# 3            Kaeo      NZ -35.1000  173.7833     70.00        72          31
# 4          Hobart      AU -42.8794  147.3294     55.99        58          40
# 5            Uray      RU  60.1247   64.7758    -12.12        90         100
# 6          Barrow      US  71.2906 -156.7887    -25.60        68          20
# 7  Ribeira Grande      PT  38.5167  -28.7000     59.00        77          40
# 8   Leningradskiy      RU  69.3833  178.4167    -14.53        82           0
# 9          Dikson      RU  73.5069   80.5464    -32.10        85          90
#
#    Wind Speed Current Description
# 0        9.22       broken clouds
# 1        1.43     overcast clouds
# 2        9.69    scattered clouds
# 3        5.99    scattered clouds
# 4       13.80    scattered clouds
# 5        9.40          light snow
# 6        9.22          few clouds
# 7        9.22    scattered clouds
# 8        6.78           clear sky
# 9       15.93     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
